# %% [markdown]
# # Week 4 - Session 2: Foundations of Machine Learning & Model Evaluation

# %% [markdown]
# # Reference Books
# ## Machine Learning
# - Best for absolute beginners:
#     - Machine Learning for Absolute Beginners by Oliver Theobald
# - Best for beginners with python experience:
#     - Introduction to Machine Learning with Python: A Guide for Data Scientists by Andreas C. Müller and Sarah Guido
# - Best for advanced learners:
#     - Machine Learning: A Probabilistic Perspective by Kevin P. Murphy
#     - Advanced Machine Learning with Python by John Hearty
# ## NumPy
# - Datacamp Documentation: https://www.datacamp.com/doc/numpy
# - NumPy Illustrated: https://medium.com/better-programming/numpy-illustrated-the-visual-guide-to-numpy-3b1d4976de1d
# - The absolute basics for beginners: https://numpy.org/devdocs/user/absolute_beginners.html
# - https://numpy.org/learn/
# ## Python
# - Fluent Python: Clear, Concise, and Effective Programming by Luciano Ramalho
# - Python for Data Analysis by Wes McKinney
# - Python Crash Course by Eric Matthes

# %% [markdown]
# ## 1. Introduction to Model Evaluation

# %% [markdown]
# - Before building complex systems, we must understand **how to determine if a machine learning model is performing well**.
# - At its core, evaluating a model means comparing **what the model thinks** will happen against **what actually happened**.

# %% [markdown]
# Every evaluation metric in machine learning relies on a side-by-side comparison between two fundamental elements:
#
# * **Prediction ($\hat{y}$):** This is the output, guess, or decision generated by our machine learning model when it is given a set of input features. It is **what the model *thinks* the answer should be**.
# * **Ground Truth ($y$):** This is the real-world, verified, and indisputable correct answer. It represents the historical reality or **the actual label** that was manually verified by humans.

# %% [markdown]
# For example, if we run an automated email classification system to spot malicious messages:
# - If an incoming email is an advertisement for a scam, its Ground Truth label is Spam.
# - If our model analyzes the email text and flags it as malicious, its Prediction is Spam.

# %% [markdown]
# #### 💡 Real-World Examples of Prediction vs. Ground Truth:
#
# 1.  **AI Customer Support Chatbot:**
#     * **Input Features:** A customer types: *"I’ve been waiting three days for my refund, this is completely unacceptable!"*
#     * **Model Prediction:** The model analyzes the text and flags the emotional intent as **"Calm / Normal Inquiry"**.
#     * **Ground Truth:** A human supervisor reviews the message and labels it as **"Highly Frustrated / Urgent"**.
#     * *Evaluation Note:* Because the prediction does not match the ground truth, the system has made an error.
#
# 2.  **Medical Diagnosis Tool:**
#     * **Input Features:** A patient's MRI scan and lab results.
#     * **Model Prediction:** The AI flags the scan as **"Malignant Tumor Detected"**.
#     * **Ground Truth:** A follow-up physical biopsy confirms the tissue is indeed **"Malignant"**.
#     * *Evaluation Note:* The prediction matches the ground truth perfectly, marking a successful classification.

# %% [markdown]
# 3.  **Real Estate Price Predictor:**
#     - **Input Features:** A house with 3 bedrooms, 2 bathrooms, located in downtown Tehran.
#     - **Model Prediction:** The model estimates the market value to be **150,000**.
#     - **Ground Truth:** The house actually sells on the market for **155,000**.
#     - *Evaluation Note:* In continuous numerical values (Regression), predictions rarely match the ground truth exactly.
#     - Evaluation here measures *how close* the prediction was to the truth (an error margin of only $5,000).

# %% [markdown]
# ## Accuracy and Error
# To measure overall performance, we look at the relationship between these two values across a large collection of examples:
#
# - **Accuracy:** This represents the overall percentage of correct predictions made by the model. If a model evaluates a batch of unseen customer inquiries and correctly identifies the category for a vast majority of them, it has a high accuracy. While a high accuracy generally indicates strong performance, it is not always a perfect indicator on its own—especially if your dataset is highly imbalanced (e.g., when 99% of your data belongs to only one category).
# $$\text{Accuracy} = \frac{\text{Number of Correct Predictions}}{\text{Total Samples}} \times 100$$
#
# - **Error:** This represents the rate or frequency at which the model makes incorrect predictions. When a model's prediction does not match the ground truth, an error occurs. The ultimate goal of training a machine learning model is to drive this error down as low as possible.
#     - If a model has an Accuracy of 92%, its Error rate is automatically 8%.
#     - If a model has an Accuracy of 60%, its Error rate is 40%.
# - **Ultimate Optimization Goals**:
#     - When training a model, the goal for Accuracy is maximization—you want to push this number as close to 100% as possible.
#     - The goal for Error is minimization—algorithms are designed to continually adjust internal parameters to drive this value down as close to 0% as possible.

# %% [markdown]
# ## Challenging the Class
#
# ### Case Study 1: The Imbalance Trap
# **Scenario:** Suppose we have a database of 1,000 customer support tickets. Out of these, 950 are ordinary, calm inquiries (Normal), and only 50 are from highly frustrated, critical customers (Urgent/Angry).
#
# If we build a completely "lazy" model that doesn't even read the incoming text but blindly labels every single ticket as "Normal", what will its Accuracy be?
#
# $$\text{Accuracy} = \frac{950}{1000} \times 100 = 95\%$$

# %% [markdown]
# ### 📊 Case Study 2: The Stakes of Cancer Detection AI
#
# To see how the cost of an error changes based on the industry, let's look at an AI diagnostic tool designed to analyze medical imaging (like mammograms or lung CT scans) to spot early-stage cancer cells.
#
# | Patient ID | Medical Scan Summary | Model Prediction | Ground Truth | Evaluation Status |
# | :---: | :--- | :---: | :---: | :---: |
# | #1 | Routine scan, clear tissue patterns. | Healthy | Healthy | Correct |
# | #2 | Visible irregular mass with dense shadowing. | Malignant (Cancer) | Malignant (Cancer) | Correct |
# | #3 | Complex but benign (safe) tissue inflammation. | Malignant (Cancer) | Healthy | **Error** |
# | #4 | Standard baseline check, no anomalies. | Healthy | Healthy | Correct |
# | #5 | Faint, early-stage microscopic cell cluster. | Healthy | Malignant (Cancer) | **Error** |
#
# ---
#
# ### 🧠 Discussion & Brain Teaser for the Class
#
# Look closely at the two completely different mistakes the model made:
# * **Patient #3:** The model predicted **Malignant**, but the Ground Truth was actually **Healthy**.
# * **Patient #5:** The model predicted **Healthy**, but the Ground Truth was actually **Malignant**.
#
# #### ❓ Questions for reflection:
# 1. What is the calculated **Accuracy** and **Error Rate** of this medical AI tool? *(Answer: 60% Accuracy, 40% Error Rate)*.
# 2. In a healthcare or clinical environment, which of these two errors is more dangerous and damaging to a patient's life? Why?
#
# ---
#
# ### 💡 The Expert Answer Key (For Class Discussion)
#
# Unlike the email spam filter where blocking a real message was worse, in **medical diagnostics, the error on Patient #5 is catastrophic.**
#
# #### 1. The Cost of a False Reassurance (Patient #5)
# * **The Error Type:** This is a **False Negative** (the model missed a real threat and labeled it safe).
# * **The Impact:** The AI tells a patient they are completely cancer-free when they are actually sick. Believing the AI, the patient goes home, misses out on early-stage treatment, and the disease continues to spread undetected.
# * **Real-World Damage:** This error directly threatens human life. By the time symptoms appear naturally, it might be too late for effective treatment. In medicine, a False Negative carries an incredibly high cost.
#
# #### 2. The Cost of a False Alarm (Patient #3)
# * **The Error Type:** This is a **False Positive** (the model flagged a healthy item as a threat).
# * **The Impact:** The AI panics and flags a healthy patient as having cancer.
# * **Real-World Damage:** While this causes emotional stress for the patient and requires the hospital to run an unnecessary secondary test (like a physical biopsy or a follow-up scan), the truth is quickly uncovered. The patient is ultimately told they are fine. It results in extra financial costs and anxiety, but it does not cost a life.
#
# ---
#
# ### 🛠️ Key Takeaway for Machine Learning Engineers
#
# This is why a generic "95% Accuracy" metric means absolutely nothing without context. If a medical AI company tells a hospital their tool is 99% accurate, an experienced engineer will immediately ask: **"Out of that 1% error rate, how many are False Negatives?"** When tuning healthcare models, engineers deliberately adjust the algorithms to be hyper-sensitive. It is much better for the AI to sound a false alarm (False Positive) on 10 healthy patients than to accidentally miss a single sick patient (False Negative).

# %% [markdown]
# ### Case Study 3: Spam Detection
# Look at the table below representing an AI email spam filter's performance on 5 sample emails.
#
# | Email ID | Email Text Snippet | Model Prediction | Ground Truth | Evaluation Status |
# | :---: | :--- | :---: | :---: | :---: |
# | #1 | "Hey, are we still meeting for lunch today?" | Not Spam | Not Spam | Correct |
# | #2 | "CONGRATULATIONS! Click here to claim your $1000 gift!" | Spam | Spam | Correct |
# | #3 | "Your monthly bank statement is ready to view." | Spam | Not Spam | **Error** |
# | #4 | "Urgent: Please review the modified project layout." | Not Spam | Not Spam | Correct |
# | #5 | "Double your crypto investment in 24 hours guaranteed!" | Not Spam | Spam | **Error** |
#
# **Questions for reflection:**
# 1. What is the calculated **Accuracy** and **Error Rate** of this spam filter? (Answer: 60% Accuracy, 40% Error).
# 2. Look closely at **Email #3** (a real bank statement blocked as spam) vs **Email #5** (a scam email that slipped into the inbox). In a real-world business environment, which of these two errors is more damaging to a user? Why?

# %% [markdown]
# # 2. What Is a Model?
#
# When we enter the field of Artificial Intelligence, the word **"Model"** is thrown around constantly. We hear about "training a model," "deploying a model," or "large language models." But what exactly *is* a model in the context of Machine Learning?
#
# To understand it like an engineer, we must strip away the hype and look at a model through two lenses:
# - as a mathematical function,
# - as a machine controlled by internal dials called parameters.
#
# ---
#
# ### A. A Model as a Mathematical Function (Input ➔ Output)
#
# In traditional software engineering, if you want a computer to solve a problem, a human programmer must manually write every single line of explicit logic. You write the rigid rules, feed in the data, and the computer computes the output.
#
# In Machine Learning, we flip this paradigm completely. **A model is simply a mathematical function ($f$) that automatically maps an Input ($X$) to an Output ($Y$).**
#
# $$\text{Input } (X) \longrightarrow \boxed{\text{ Model } f(X)} \longrightarrow \text{ Output } (Y)$$
#
# * **Input ($X$):** These are the features, characteristics, or raw historical data points that we feed into the system.
# * **Output ($Y$):** This is the final prediction, decision, or classification value generated by the model.
# * **The Model ($f$):** This is the mathematical box that translates $X$ into $Y$. Instead of a human writing the internal logic of $f$, a Machine Learning algorithm automatically discovers the shape and rules of this function by analyzing thousands of historical examples.
#
# #### 💡 Real-World Examples of the Input-Output Mapping:
#
# 1.  **House Price Predictor:**
#     * *Input ($X$):* House Size (sq ft), Number of Bedrooms, Neighborhood Crime Rate.
#     * *Output ($Y$):* Market Price in Dollars.
# 2.  **Email Spam Filter:**
#     * *Input ($X$):* The raw text content of an incoming email converted to numbers.
#     * *Output ($Y$):* A probability score (e.g., 0.98 = 98 percent chance it is Spam).
# 3.  **Autonomous Vehicle Braking System:**
#     * *Input ($X$):* Distance to the closest object in front of the car (meters), Current Speed (km/h).
#     * *Output ($Y$):* Brake Pressure percentage needed (0 to 100 percent).
#
# ---
#
# ### B. Inside the Box: Understanding Model Parameters
#
# If a model is just a mathematical function, what makes it adjustable? Why does it get smarter over time? The secret lies in **Model Parameters** (commonly referred to as *Weights* and *Biases*).
#
# Think of a machine learning model as a massive electronic control console covered in **thousands or millions of internal knobs and sliders**.
#
#
#
# * Each knob represents a **Parameter**—a number that controls how much weight the model gives to a specific input feature.
# * **When a model is first created, all these knobs are set completely at random.** If you pass a house size into a newly created model, it might guess the price is negative three dollars because its internal knobs are uncalibrated.
# * The model has no inherent "wisdom" out of the box; it only has the potential to learn based on how these knobs are configured.
#
# #### 🏠 Let's look at a simple house pricing scenario:
# Imagine our model uses a simplified internal equation to calculate price based on house size:
# $$\text{Predicted Price} = (\text{House Size} \times \textbf{Knob A}) + \textbf{Knob B}$$
#
# * **Knob A (Weight):** Controls *how intensely* the size of the house impacts the price. If Knob A is set to a high positive number, a small increase in house size dramatically spikes the predicted price.
# * **Knob B (Bias):** Acts as a baseline starting value. It represents what a house would cost even if its size features were minimal (a baseline property value).
#
# ---
#
# #### Training: The Process of Finding the Best Parameter Values
#
# If the knobs start out random, how do they find the perfect settings? This is the core definition of **Training**.
#
# Training a model is the automated, algorithmic process of adjusting the model's internal parameters (the knobs) until its predictions align as closely as possible with reality (the ground truth).
#
#
# **[Random Knobs] ➔ Predict ➔ Compare with Truth ➔ Calculate Error ➔ Tweak Knobs Slightly ➔ [Better Knobs]**

# %% [markdown]
# 1. **The Starting State:** We feed an input (e.g., a 2,000 sq ft house) into our model with random parameters. The model predicts a chaotic price (e.g., 5,000 USD).
# 2. **The Reality Check:** The training algorithm looks at the Ground Truth (the house actually sold for $300,000) and realizes the model missed by an enormous margin.
# 3. **The Adjustment:** An optimization algorithm computes exactly how much, and in which direction, to turn Knob A and Knob B to make the error smaller next time. (Maybe it turns Knob A clockwise to give house size more positive value).
# 4. **The Loop:** This cycle is repeated millions of times across a massive database of historical examples. Step by step, the knobs stop fluctuating wildly and settle into their optimal parameter values.
#
# Once the knobs stop moving and the error reaches its lowest point, we declare that the model is trained and ready to make predictions on data it has never seen before.

# %% [markdown]
# ### Caste Study 4: Student Final Exam Scores
#
# Consider mathematical function predicting **Student Final Exam Scores** (0 to 100):
# $$\text{Predicted Score} = (X1 \times \textbf{Weight 1}) + (X2 \times \textbf{Weight 2}) + \textbf{Bias}$$
#
# * `X1` = Total hours spent studying.
# * `X2` = Total hours spent playing video games the night before the exam.
#
# #### ❓ Discussion Questions:
# 1.  Once the model is fully trained and highly accurate, do you expect **Weight 1** to be a **positive** or **negative** number? Why?
# 2.  Do you expect **Weight 2** to be a **positive** or **negative** number? Why?
# 3.  What real-world concept does the **Bias** parameter represent here? What does it mean if a student's $X1$ and $X2$ are both exactly `0`? Can a bias parameter be negative?

# %% [markdown]
# # 3. The Model Training Process
#
#
# Now that we understand what a model is—a mathematical box controlled by adjustable knobs called **parameters**—we need to look at the exact engineering blueprint used to tune those parameters.
#
# In machine learning, we don't magically discover the perfect parameter settings. Instead, data flows through a highly structured, repetitive pipeline. This lifecycle is known as the **Model Training Process**.
#
# ---
#
# ## A. The Core Pipeline: A Structural Overview
#
# Every standard machine learning workflow follows a continuous loop. Until the model reaches satisfactory performance, data repeatedly moves through the following stages:
#
# ```text
# Data
#    ↓
# Preprocessing
#    ↓
# Model
#    ↓
# Prediction
#    ↓
# Loss
#    ↓
# Optimization
#    ↓
# Updated Model
#    ↺ (Repeat)
# ```
#
# Let's examine each stage in detail.
#
# ---
#
# ## B. Detailed Step-by-Step Breakdown
#
# ### 1. Data (The Raw Material)
#
# Before an algorithm can learn, it needs historical examples.
#
# **Concept**
#
# Data consists of historical records containing:
#
# - **Features (X):** The input information.
# - **Ground Truth Labels (y):** The correct answers that the model should learn to predict.
#
# **Example**
#
# Suppose we are building an email classification system.
#
# Our dataset contains:
#
# - 5,000 customer emails
# - Labels indicating whether each email is:
#   - Urgent
#   - Normal
#   - Spam
#
# ---
#
# ### 2. Preprocessing (The Translation Stage)
#
# Computers cannot directly understand text, images, or audio. They only understand numbers.
#
# **Concept**
#
# Preprocessing transforms raw data into clean numerical representations that machine learning algorithms can process.
#
# Typical preprocessing tasks include:
#
# - Removing punctuation
# - Converting text into numbers (vectorization)
# - Handling missing values
# - Normalizing numerical values
# - Removing corrupted records
#
# **Example**
#
# Raw email:
#
# ```text
# URGENT RESET MY PASSWORD!!!
# ```
#
# After preprocessing, it might become a numerical vector such as:
#
# ```text
# [1.0, 0.0, 0.0, 1.0 0.5]
# ```
#
# *(The actual numbers depend on the encoding technique.)*
#
# ---
#
# ### 3. Model (The Mathematical Blueprint)
#
# The model is a mathematical function:
#
# $$
# \hat{y}=f(X)
# $$
#
# Initially, all **weights** and **biases** are assigned random values.
#
# At this point, the model has **not learned anything**.
#
# It simply waits to receive numerical inputs.
#
# ---
#
# ### 4. Prediction (The Guess)
#
# The processed features are fed into the model.
#
# **Concept**
#
# The model produces its current best estimate:
#
# $$
# \hat{y}
# $$
#
# Since the parameters are still random during early training, the prediction is often poor.
#
# **Example**
#
# Input:
#
# ```text
# URGENT RESET MY PASSWORD
# ```
#
# Model output:
#
# > Probability of being urgent = **12%**
#
# ---
#
# ### 5. Loss Function (The Reality Check)
#
# Now we compare the prediction with the correct answer.
#
# **Concept**
#
# A **Loss Function** measures how wrong the prediction is.
#
# It compares:
#
# - Prediction: $\hat{y}$
# - Ground Truth: $y$
#
# and produces a single error value called the **Loss**.
#
# **Interpretation**
#
# - Loss = **0**
#   - Perfect prediction
# - Larger Loss
#   - Worse prediction
#
# **Example**
#
# Actual label:
#
# ```text
# Urgent = 100%
# ```
#
# Predicted probability:
#
# ```text
# Urgent = 12%
# ```
#
# Loss might be:
#
# ```text
# Loss = 0.88
# ```
#
# A high loss means the prediction is far from the correct answer.
#
# ---
#
# ### 6. Optimization (The Learning Engine)
#
# Knowing the model is wrong is not enough.
#
# We also need to know **how to improve it**.
#
# This is the **optimizer**'s job.
#
# **Concept**
#
# The optimizer examines the loss and determines:
#
# - Which parameters should change
# - How much they should change
# - In which direction they should change
#
# Its objective is simple:
#
# > **Reduce the loss during the next prediction.**
#
# **Example**
#
# The optimizer determines that the weight associated with the word:
#
# ```text
# URGENT
# ```
#
# should be increased because it strongly indicates an urgent email.
#
# ---
#
# ### 7. Updated Model (The Improved Version)
#
# The optimizer updates the weights and biases.
#
# The model is now slightly better than before.
#
# Then the process repeats with the next batch of training data.
#
# Each repetition gradually improves the model's predictions.
#
# ---
#
# ## C. The Iterative Concept of an Epoch
#
# Training is **not** a one-time process.
#
# The entire pipeline runs repeatedly.
#
# ### What is an Epoch?
#
# An **Epoch** means:
#
# > The model has processed **every training sample exactly once**.
#
# ---
#
# ### Why Do We Need Multiple Epochs?
#
# After seeing only one example, the model changes very little.
#
# It must repeatedly review the entire dataset to gradually improve.
#
# Many real-world models require:
#
# - 10 epochs
# - 50 epochs
# - 100 epochs
# - Sometimes even thousands of epochs
#
# Each epoch makes the parameters slightly more accurate.
#
# ---
#
# ### Loss Curve
#
# During training, we often plot the **Loss** after each epoch.
#
# A successful training process produces a graph like this:
#
# ```text
# Loss
#  ^
#  |\
#  | \
#  |  \
#  |   \
#  |    \______
#  +--------------------> Epoch
# ```
#
# A steadily decreasing loss indicates that the model is learning successfully.
#
# ---
#
# ## 🧠 Quick Check for the Class
#
# Suppose we observe the following training statistics.
#
# | Epoch | Loss | Accuracy |
# |-------:|-----:|---------:|
# | 1 | 4.52 | 21% |
# | 100 | 0.08 | 94% |
#
# ### Reflection Question
#
# What happened to the model's internal **weights** and **biases** between Epoch 1 and Epoch 100?
#
# Which step in the training pipeline was responsible for those changes?
#
# > **Answer:** The **Optimizer** repeatedly updated the model's parameters based on the **Loss Function**, gradually adjusting the weights and biases from random initial values toward settings that better matched the ground truth. As a result, the loss decreased and the prediction accuracy improved dramatically.

# %% [markdown]
# # 4. Overfitting and Underfitting
#
# The primary goal of any machine learning model is **Generalization**—the ability to look at fresh, brand-new data that it has never seen before and output highly accurate predictions.
#
# However, finding the perfect balance where a model generalizes well is one of the most difficult challenges in AI. If we configure our mathematical function poorly, it will fall into one of two classic traps: **Underfitting** or **Overfitting**.
#
# ---

# %% [markdown]
# ### A. The Three Degrees of Model Fit
#
# To understand these concepts, let's look at how three different models attempt to map out a boundary line between two classes of data, or a trend line tracking values.
#
#
#
# #### 1. Underfitting (High Bias)
# * **What it is:** Underfitting occurs when a model is **too simple** or lacks the capacity to capture the underlying structure and true relationships hidden within the data.
# * **The Result:** The model performs poorly on your training data **AND** poorly on your test data. It has high error rates across the board because it completely missed the pattern.
# * **Example:** Imagine trying to predict a person's health profile using only their height, completely ignoring their diet, genetics, and exercise habits. The model is too simple to ever be accurate.
#
# #### 2. Good Fit (The Sweet Spot)
# * **What it is:** This is the ideal scenario. The model is complex enough to capture the true underlying trends, but simple enough to ignore random fluctuations or background noise.
# * **The Result:** Low error rates and highly consistent, reliable performance on both the training data and unseen future data.
#
# #### 3. Overfitting (High Variance)
# * **What it is:** Overfitting occurs when a model is **too complex** and learns the training dataset *too well*. Instead of discovering general rules, it essentially memorizes every single data row, along with all of its random background noise, typos, and flukes.
# * **The Result:** Flawless, near-perfect performance on the training data, but terrible, highly inaccurate performance on new, unseen test data.
#
# ---

# %% [markdown]
# ### B. Understanding the "Student Analogy"
#
# To cement these three states in your mind, imagine three different students studying for a final exam using a packet of 50 practice homework questions:
#
# * **The Underfitted Student:** Only skims a single page of the study guide. They fail to understand the core concepts and score terribly on both the practice homework and the actual final exam.
# * **The Well-Generalized Student:** Studies the core theories deeply and practices a diverse range of problems. Even though they might miss a tricky question on the homework, they understand the underlying rules and pass the brand-new final exam with flying colors.
# * **The Overfitted Student:** Word-for-word memorizes the exact answer key of the 50 practice questions without understanding the math. They score a perfect 100% on the practice assignments. However, they completely fail the final exam because the teacher changed the numbers and phrasing on the real test.
#
# | Metric / Feature | Underfitting | Good Fit | Overfitting |
# | :--- | :---: | :---: | :---: |
# | **Training Set Performance** | Poor | Good | Near Perfect |
# | **Test Set Performance** | Poor | Good | Poor |
# | **Model State** | Too Simple | Balanced | Too Complex |
# | **Core Issue** | Didn't learn the pattern | Learns the pattern | Memorized the noise |
#
# ---

# %% [markdown]
# ### C. Intuitive Bias vs. Variance
#
# In machine learning literature, underfitting and overfitting are formally described using two statistical terms: **Bias** and **Variance**.
#
# * **Bias (The Rigid Thinker):** Bias represents the oversimplified assumptions made by a model. If a model has *High Bias*, it means it approaches a problem with rigid, inflexible ideas. No matter how much data you throw at it, it refuses to learn complex nuances, leading to **Underfitting**.
# * **Variance (The Reactive Panic):** Variance represents how sensitive a model is to minor fluctuations in the specific training data it was shown. If a model has *High Variance*, it changes its internal mathematical logic wildly based on tiny, random variations in the training rows, leading to **Overfitting**.
#
# ---
#
# ### D. The Interplay of Model Complexity and Data Volume
#
# How do we control whether a model underfits or overfits? We manipulate two primary engineering levers:
#
# #### Lever 1: Model Complexity
# As you increase a model's complexity (e.g., adding more parameters, creating deeper networks, or feeding it more interactive features), its capacity to fit intricate patterns increases.
#
#
#
# * If complexity is **too low**, the model can't learn (Underfitting / High Bias).
# * If complexity is **too high**, the model moves past learning the pattern and starts memorizing the noise (Overfitting / High Variance).
# * **The Engineer's Goal:** Find the "Sweet Spot" where the validation error is at its lowest possible point before it starts spiking back up.
#
# #### Lever 2: Data Volume
# Data volume is your strongest weapon against overfitting.
# * Imagine an overfitted model trying to memorize the specific traits of 10 customer emails. It can easily memorize every single word.
# * Now, imagine feeding that same model **100,000 customer emails**.
# * It is mathematically impossible for the model's parameters to memorize 100,000 unique sentences. The model is forced to abandon rote memorization and must adapt by finding the genuine, shared, underlying linguistic patterns.
#
# > **Key Takeaway:** Increasing model complexity allows you to escape underfitting, while increasing your data volume allows you to escape overfitting.
#
# ---
#
# ### 🧠 Quick Check for the Class
#
# **Scenario:** You are training a machine learning model to detect credit card fraud. You let the model train for a very long time. When you check your logs, you see the following metrics:
# * Accuracy on **Training Data**: 99.9%
# * Accuracy on **Test Data**: 71.2%
#
# **Questions for Discussion:**
# 1. Is this model suffering from Underfitting or Overfitting?
# 2. Based on what you know about model complexity and data volume, what are two concrete actions you could take to fix this model's performance?

# %% [markdown]
# # 5. Dataset Splitting
#
#
# To accurately monitor, diagnose, and prevent **overfitting** or **underfitting** throughout the machine learning lifecycle, we cannot evaluate our models on the same data they learned from.
#
# Doing so creates a serious problem known as **Data Leakage**.
#
# Imagine giving a student the exact questions from the final exam before the test. A perfect score would only prove memorization—not true understanding.
#
# To prevent this, we divide our dataset into **three completely separate subsets**:
#
# - **Training Set**
# - **Validation Set**
# - **Test Set**
#
# ---
#
# ## A. The Three Data Subsets
#
# ### 1. Training Set (The Textbook)
#
# **Typical Allocation**
#
# - **70%–80%** of the total dataset
#
# **Purpose**
#
# The training set is the data from which the model actually learns.
#
# **How It Works**
#
# During training:
#
# - The model receives the input features.
# - It makes predictions.
# - The loss is calculated.
# - The optimizer updates the model's weights and biases.
#
# Only the **training set** is used to modify the model's parameters.
#
# ---
#
# ### 2. Validation Set (The Mock Exams)
#
# **Typical Allocation**
#
# - **10%–15%** of the total dataset
#
# **Purpose**
#
# The validation set helps monitor the model during development.
#
# It is mainly used to:
#
# - Detect overfitting
# - Tune hyperparameters
# - Decide when to stop training (Early Stopping)
#
# **How It Works**
#
# The model **never learns** from the validation data.
#
# Instead, after each epoch (or every few epochs), the model is evaluated on the validation set.
#
# Possible outcomes:
#
# - **Training Loss ↓** and **Validation Loss ↓**
#   - The model is learning well.
#
# - **Training Loss ↓** but **Validation Loss ↑**
#   - The model has started **overfitting**.
#
# Engineers use this information to improve the model before final testing.
#
# ---
#
# ### 3. Test Set (The Final Exam)
#
# **Typical Allocation**
#
# - **10%–15%** of the total dataset
#
# **Purpose**
#
# The test set measures the model's true performance on completely unseen data.
#
# **How It Works**
#
# The test set remains hidden throughout:
#
# - Training
# - Validation
# - Hyperparameter tuning
#
# Only after development is completely finished is the model evaluated on the test set.
#
# This provides an unbiased estimate of how well the model will perform in the real world.
#
# ---
#
# ## B. A Complete Real-World Example
#
# ### Customer Support Email Classification
#
# Imagine a company wants to build an AI system that automatically categorizes customer emails.
#
# ### Dataset
#
# The company has:
#
# - **10,000** historical customer emails
#
# Each email has already been manually labeled with its correct category, such as:
#
# - Billing Error
# - Password Reset
# - Cancellation Request
#
# The engineering team chooses an **80 / 10 / 10** split.
#
# ```text
# Total Dataset: 10,000 Customer Emails
#
# ├── Training Set (80%)    → 8,000 Emails
# │      Used for learning
# │
# ├── Validation Set (10%)  → 1,000 Emails
# │      Used during development
# │
# └── Test Set (10%)        → 1,000 Emails
#        Used only once after training
# ```
#
# ---
#
# ### The Training Lifecycle
#
# #### Step 1: Initial Training
#
# The model repeatedly learns from the **8,000 training emails**.
#
# After every few epochs, engineers evaluate it using the **1,000 validation emails**.
#
# Results:
#
# - Training Accuracy ↑
# - Validation Accuracy ↑
#
# This indicates healthy learning.
#
# ---
#
# #### Step 2: Overfitting Appears
#
# After about **100 epochs**:
#
# - Training Accuracy = **99%**
# - Validation Accuracy drops from **88%** to **74%**
#
# Diagnosis:
#
# The model has begun memorizing the training emails instead of learning general patterns.
#
# This is **Overfitting**.
#
# ---
#
# #### Step 3: Fixing the Problem
#
# The engineers:
#
# - Stop training
# - Reduce model complexity
# - Retrain the model
#
# New results:
#
# - Training Accuracy = **90%**
# - Validation Accuracy = **88%**
#
# The gap between training and validation performance is now much smaller.
#
# ---
#
# #### Step 4: Final Evaluation
#
# Now the team finally unlocks the **1,000 test emails**.
#
# These emails have never been seen before.
#
# Results:
#
# - Test Accuracy = **87.5%**
#
# Because the test accuracy is very close to the validation accuracy, the engineers conclude that the model generalizes well and is ready for production.
#
# ---
#
# ## C. Why Do We Need Three Separate Sets?
#
# | Dataset | Purpose | Used for Learning? |
# |----------|----------|-------------------|
# | **Training Set** | Learn patterns | ✅ Yes |
# | **Validation Set** | Monitor learning and tune the model | ❌ No |
# | **Test Set** | Final unbiased evaluation | ❌ No |
#
# ---
#
# ## 🧠 Quick Check for the Class
#
# ### Scenario
#
# A junior developer splits their data into only:
#
# - Training Set
# - Test Set
#
# They completely skip creating a validation set.
#
# The model trains for **500 epochs**.
#
# Only after training finishes do they evaluate the model on the test set.
#
# The test accuracy is terrible.
#
# ### Reflection Questions
#
# 1. Why did skipping the validation set leave the developer blind during training?
#
# 2. How could a validation set have saved time before reaching the final testing stage?
#
# > **Answer:** Without a validation set, the developer had no way to monitor how well the model generalized during training. They could not detect the moment when the model began overfitting, so training continued far longer than necessary. A validation set would have revealed the performance decline early, allowing techniques such as **Early Stopping** or model simplification before wasting time on hundreds of unnecessary epochs.
